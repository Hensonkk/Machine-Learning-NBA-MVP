# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.metrics import accuracy_score, classification_report

# %%
player_stats = pd.read_csv("Data/cleaned_NBA_stats.csv")

# %% [markdown]
# ## Building the Model

# %%
# Determine features and target for Stats vs MVP/Non-MVP model testing (Use top 12 stats from MVP/Non-MVP correlation)
features = ['G', 'PTS', 'MP', 'AST', 'TRB', 'FG%', 'FGA','FT%']

X = player_stats[features]
y = player_stats['Share']

# Scale/Standardize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)


# Split data into training and test datasets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, random_state = 42)

# Build the model
inputs = X_train.shape[1]
hidden_nodes_l1 = 60
hidden_nodes_l2 = 40
hidden_nodes_l3 = 20
model = Sequential()

# First Hidden Layer
model.add(Dense(units = hidden_nodes_l1, activation = 'relu', input_dim = inputs))

# Second Hidden Layer
model.add(Dense(units = hidden_nodes_l2, activation = 'relu'))

# Third Hidden Layer
model.add(Dense(units = hidden_nodes_l3, activation = 'relu'))

# Output Layer
model.add(Dense(units = 1, activation = 'sigmoid'))

# Check model structure
model.summary()

# Compile model
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# Train model
model.fit(X_train, y_train, epochs = 15, batch_size = 25, validation_data = (X_test, y_test))

# Evaluate the model using the test data
loss, accuracy = model.evaluate(X_test ,y_test)
print(f"Test Loss: {round(loss,2)*100}%, Test Accuracy: {round(accuracy,2)*100}%")

model_original = pd.DataFrame({'Loss': [round(loss,2)], 'Accuracy': [round(accuracy,2)]})
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 60)                540
#
#  dense_1 (Dense)             (None, 40)                2440
#
#  dense_2 (Dense)             (None, 20)                820
#
#  dense_3 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 3821 (14.93 KB)
# Trainable params: 3821 (14.93 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/15
# 439/439 [==============================] - 1s 827us/step - loss: 0.0546 - accuracy: 0.9666 - val_loss: 0.0201 - val_accuracy: 0.9675
# Epoch 2/15
# 439/439 [==============================] - 0s 695us/step - loss: 0.0185 - accuracy: 0.9666 - val_loss: 0.0175 - val_accuracy: 0.9675
# Epoch 3/15
# 439/439 [==============================] - 0s 794us/step - loss: 0.0164 - accuracy: 0.9666 - val_loss: 0.0161 - val_accuracy: 0.9675
# Epoch 4/15
# 439/439 [==============================] - 0s 729us/step - loss: 0.0157 - accuracy: 0.9666 - val_loss: 0.0159 - val_accuracy: 0.9675
# Epoch 5/15
# 439/439 [==============================] - 0s 706us/step - loss: 0.0150 - accuracy: 0.9666 - val_loss: 0.0152 - val_accuracy: 0.9675
# Epoch 6/15
# 439/439 [==============================] - 0s 741us/step - loss: 0.0150 - accuracy: 0.9666 - val_loss: 0.0153 - val_accuracy: 0.9675
# Epoch 7/15
# 439/439 [==============================] - 0s 695us/step - loss: 0.0146 - accuracy: 0.9666 - val_loss: 0.0154 - val_accuracy: 0.9675
# Epoch 8/15
# 439/439 [==============================] - 0s 676us/step - loss: 0.0147 - accuracy: 0.9666 - val_loss: 0.0145 - val_accuracy: 0.9675
# Epoch 9/15
# 439/439 [==============================] - 0s 680us/step - loss: 0.0144 - accuracy: 0.9666 - val_loss: 0.0148 - val_accuracy: 0.9675
# Epoch 10/15
# 439/439 [==============================] - 0s 676us/step - loss: 0.0143 - accuracy: 0.9666 - val_loss: 0.0160 - val_accuracy: 0.9675
# Epoch 11/15
# 439/439 [==============================] - 0s 687us/step - loss: 0.0140 - accuracy: 0.9666 - val_loss: 0.0148 - val_accuracy: 0.9675
# Epoch 12/15
# 439/439 [==============================] - 0s 680us/step - loss: 0.0140 - accuracy: 0.9666 - val_loss: 0.0158 - val_accuracy: 0.9675
# Epoch 13/15
# 439/439 [==============================] - 0s 686us/step - loss: 0.0139 - accuracy: 0.9666 - val_loss: 0.0145 - val_accuracy: 0.9675
# Epoch 14/15
# 439/439 [==============================] - 0s 701us/step - loss: 0.0138 - accuracy: 0.9666 - val_loss: 0.0146 - val_accuracy: 0.9675
# Epoch 15/15
# 439/439 [==============================] - 0s 686us/step - loss: 0.0138 - accuracy: 0.9666 - val_loss: 0.0152 - val_accuracy: 0.9675
# 115/115 [==============================] - 0s 336us/step - loss: 0.0152 - accuracy: 0.9675
# Test Loss: 2.0%, Test Accuracy: 97.0%

# %%
# First Attempt (Using new number of neurons and less epochs)

# Build the model
inputs = X_train.shape[1]
hidden_nodes_l1 = 100
hidden_nodes_l2 = 60
hidden_nodes_l3 = 30
model = Sequential()

# First Hidden Layer
model.add(Dense(units = hidden_nodes_l1, activation = 'relu', input_dim = inputs))

# Second Hidden Layer
model.add(Dense(units = hidden_nodes_l2, activation = 'relu'))

# Third Hidden Layer
model.add(Dense(units = hidden_nodes_l3, activation = 'relu'))

# Output Layer
model.add(Dense(units = 1, activation = 'sigmoid'))

# Check model structure
model.summary()

# Compile model
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# Train model
model.fit(X_train, y_train, epochs = 10, batch_size = 25, validation_data = (X_test, y_test))

# Evaluate the model using the test data
loss, accuracy = model.evaluate(X_test ,y_test)
print(f"Test Loss: {round(loss,2)*100}%, Test Accuracy: {round(accuracy,2)*100}%")

Optimizing_1 = pd.DataFrame({'Loss': [round(loss,2)], 'Accuracy': [round(accuracy,2)]})
Optimizing_1
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 100)               900
#
#  dense_5 (Dense)             (None, 60)                6060
#
#  dense_6 (Dense)             (None, 30)                1830
#
#  dense_7 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 8821 (34.46 KB)
# Trainable params: 8821 (34.46 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 439/439 [==============================] - 1s 828us/step - loss: 0.0506 - accuracy: 0.9663 - val_loss: 0.0188 - val_accuracy: 0.9675
# Epoch 2/10
# 439/439 [==============================] - 0s 737us/step - loss: 0.0177 - accuracy: 0.9666 - val_loss: 0.0179 - val_accuracy: 0.9675
# Epoch 3/10
# 439/439 [==============================] - 0s 726us/step - loss: 0.0168 - accuracy: 0.9666 - val_loss: 0.0154 - val_accuracy: 0.9675
# Epoch 4/10
# 439/439 [==============================] - 0s 721us/step - loss: 0.0155 - accuracy: 0.9666 - val_loss: 0.0153 - val_accuracy: 0.9675
# Epoch 5/10
# 439/439 [==============================] - 0s 709us/step - loss: 0.0153 - accuracy: 0.9666 - val_loss: 0.0157 - val_accuracy: 0.9675
# Epoch 6/10
# 439/439 [==============================] - 0s 703us/step - loss: 0.0150 - accuracy: 0.9666 - val_loss: 0.0161 - val_accuracy: 0.9675
# Epoch 7/10
# 439/439 [==============================] - 0s 700us/step - loss: 0.0151 - accuracy: 0.9666 - val_loss: 0.0164 - val_accuracy: 0.9675
# Epoch 8/10
# 439/439 [==============================] - 0s 699us/step - loss: 0.0145 - accuracy: 0.9666 - val_loss: 0.0191 - val_accuracy: 0.9675
# Epoch 9/10
# 439/439 [==============================] - 0s 710us/step - loss: 0.0146 - accuracy: 0.9666 - val_loss: 0.0145 - val_accuracy: 0.9675
# Epoch 10/10
# 439/439 [==============================] - 0s 700us/step - loss: 0.0143 - accuracy: 0.9666 - val_loss: 0.0167 - val_accuracy: 0.9675
# 115/115 [==============================] - 0s 339us/step - loss: 0.0167 - accuracy: 0.9675
# Test Loss: 2.0%, Test Accuracy: 97.0%
#    Loss  Accuracy
# 0  0.02      0.97

# %%
# Second Attempt (Using additional hidden layer)

# Build the model
inputs = X_train.shape[1]
hidden_nodes_l1 = 100
hidden_nodes_l2 = 80
hidden_nodes_l3 = 60
hidden_nodes_l4 = 40
model = Sequential()

# First Hidden Layer
model.add(Dense(units = hidden_nodes_l1, activation = 'relu', input_dim = inputs))

# Second Hidden Layer
model.add(Dense(units = hidden_nodes_l2, activation = 'relu'))

# Third Hidden Layer
model.add(Dense(units = hidden_nodes_l3, activation = 'relu'))

# Fourth Hidden Layer
model.add(Dense(units = hidden_nodes_l4, activation = 'relu'))

# Output Layer
model.add(Dense(units = 1, activation = 'sigmoid'))

# Check model structure
model.summary()

# Compile model
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# Train model
model.fit(X_train, y_train, epochs = 10, batch_size = 25, validation_data = (X_test, y_test))

# Evaluate the model using the test data
loss, accuracy = model.evaluate(X_test ,y_test)
print(f"Test Loss: {round(loss,2)*100}%, Test Accuracy: {round(accuracy,2)*100}%")

Optimizing_2 = pd.DataFrame({'Loss': [round(loss,2)], 'Accuracy': [round(accuracy,2)]})
Optimizing_2
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 100)               900
#
#  dense_9 (Dense)             (None, 80)                8080
#
#  dense_10 (Dense)            (None, 60)                4860
#
#  dense_11 (Dense)            (None, 40)                2440
#
#  dense_12 (Dense)            (None, 1)                 41
#
# =================================================================
# Total params: 16321 (63.75 KB)
# Trainable params: 16321 (63.75 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 439/439 [==============================] - 1s 909us/step - loss: 0.0460 - accuracy: 0.9651 - val_loss: 0.0181 - val_accuracy: 0.9675
# Epoch 2/10
# 439/439 [==============================] - 0s 811us/step - loss: 0.0178 - accuracy: 0.9666 - val_loss: 0.0178 - val_accuracy: 0.9675
# Epoch 3/10
# 439/439 [==============================] - 0s 850us/step - loss: 0.0167 - accuracy: 0.9666 - val_loss: 0.0186 - val_accuracy: 0.9675
# Epoch 4/10
# 439/439 [==============================] - 0s 844us/step - loss: 0.0166 - accuracy: 0.9666 - val_loss: 0.0157 - val_accuracy: 0.9675
# Epoch 5/10
# 439/439 [==============================] - 0s 797us/step - loss: 0.0150 - accuracy: 0.9666 - val_loss: 0.0162 - val_accuracy: 0.9675
# Epoch 6/10
# 439/439 [==============================] - 0s 829us/step - loss: 0.0151 - accuracy: 0.9666 - val_loss: 0.0176 - val_accuracy: 0.9675
# Epoch 7/10
# 439/439 [==============================] - 0s 805us/step - loss: 0.0150 - accuracy: 0.9666 - val_loss: 0.0153 - val_accuracy: 0.9675
# Epoch 8/10
# 439/439 [==============================] - 0s 794us/step - loss: 0.0146 - accuracy: 0.9666 - val_loss: 0.0203 - val_accuracy: 0.9675
# Epoch 9/10
# 439/439 [==============================] - 0s 794us/step - loss: 0.0148 - accuracy: 0.9666 - val_loss: 0.0154 - val_accuracy: 0.9675
# Epoch 10/10
# 439/439 [==============================] - 0s 799us/step - loss: 0.0139 - accuracy: 0.9666 - val_loss: 0.0158 - val_accuracy: 0.9675
# 115/115 [==============================] - 0s 360us/step - loss: 0.0158 - accuracy: 0.9675
# Test Loss: 2.0%, Test Accuracy: 97.0%
#    Loss  Accuracy
# 0  0.02      0.97

# %%
# Third Attempt (Using different number of neurons, epochs and learning rate)
from keras.optimizers import Adam

# Build the model
inputs = X_train.shape[1]
hidden_nodes_l1 = 100
hidden_nodes_l2 = 80
hidden_nodes_l3 = 60
model = Sequential()

# First Hidden Layer
model.add(Dense(units = hidden_nodes_l1, activation = 'relu', input_dim = inputs))

# Second Hidden Layer
model.add(Dense(units = hidden_nodes_l2, activation = 'relu'))

# Third Hidden Layer
model.add(Dense(units = hidden_nodes_l3, activation = 'relu'))

# Output Layer
model.add(Dense(units = 1, activation = 'sigmoid'))

# Check model structure
model.summary()

# Compile model
optimizer = Adam(learning_rate=0.001)
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# Train model
model.fit(X_train, y_train, epochs = 10, batch_size = 25, validation_data = (X_test, y_test))

# Evaluate the model using the test data
loss, accuracy = model.evaluate(X_test ,y_test)
print(f"Test Loss: {round(loss,2)*100}%, Test Accuracy: {round(accuracy,2)*100}%")

Optimizing_3 = pd.DataFrame({'Loss': [round(loss,2)], 'Accuracy': [round(accuracy,2)]})
Optimizing_3
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_13 (Dense)            (None, 100)               900
#
#  dense_14 (Dense)            (None, 80)                8080
#
#  dense_15 (Dense)            (None, 60)                4860
#
#  dense_16 (Dense)            (None, 1)                 61
#
# =================================================================
# Total params: 13901 (54.30 KB)
# Trainable params: 13901 (54.30 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/10
# 439/439 [==============================] - 1s 837us/step - loss: 0.0422 - accuracy: 0.9664 - val_loss: 0.0250 - val_accuracy: 0.9675
# Epoch 2/10
# 439/439 [==============================] - 0s 733us/step - loss: 0.0179 - accuracy: 0.9666 - val_loss: 0.0168 - val_accuracy: 0.9675
# Epoch 3/10
# 439/439 [==============================] - 0s 762us/step - loss: 0.0170 - accuracy: 0.9666 - val_loss: 0.0154 - val_accuracy: 0.9675
# Epoch 4/10
# 439/439 [==============================] - 0s 735us/step - loss: 0.0155 - accuracy: 0.9666 - val_loss: 0.0154 - val_accuracy: 0.9675
# Epoch 5/10
# 439/439 [==============================] - 0s 719us/step - loss: 0.0160 - accuracy: 0.9666 - val_loss: 0.0165 - val_accuracy: 0.9675
# Epoch 6/10
# 439/439 [==============================] - 0s 720us/step - loss: 0.0154 - accuracy: 0.9666 - val_loss: 0.0144 - val_accuracy: 0.9675
# Epoch 7/10
# 439/439 [==============================] - 0s 726us/step - loss: 0.0149 - accuracy: 0.9666 - val_loss: 0.0171 - val_accuracy: 0.9675
# Epoch 8/10
# 439/439 [==============================] - 0s 723us/step - loss: 0.0148 - accuracy: 0.9666 - val_loss: 0.0150 - val_accuracy: 0.9675
# Epoch 9/10
# 439/439 [==============================] - 0s 719us/step - loss: 0.0148 - accuracy: 0.9666 - val_loss: 0.0153 - val_accuracy: 0.9675
# Epoch 10/10
# 439/439 [==============================] - 0s 760us/step - loss: 0.0143 - accuracy: 0.9666 - val_loss: 0.0218 - val_accuracy: 0.9664
# 115/115 [==============================] - 0s 345us/step - loss: 0.0218 - accuracy: 0.9664
# Test Loss: 2.0%, Test Accuracy: 97.0%
#    Loss  Accuracy
# 0  0.02      0.97

# %%
# Optimizing (Using different learning rate, layers and hidden nodes)
# Final Attempt
from keras.optimizers import Adam

# Build the model
inputs = X_train.shape[1]
hidden_nodes_l1 = 100
hidden_nodes_l2 = 80
hidden_nodes_l3 = 60
hidden_nodes_l4 = 40
hidden_nodes_l5 = 30
model = Sequential()

# First Hidden Layer
model.add(Dense(units = hidden_nodes_l1, activation = 'relu', input_dim = inputs))

# Second Hidden Layer
model.add(Dense(units = hidden_nodes_l2, activation = 'relu'))

# Third Hidden Layer
model.add(Dense(units = hidden_nodes_l3, activation = 'relu'))

# Fourth Hidden Layer
model.add(Dense(units = hidden_nodes_l4, activation = 'relu'))

# Fifth Hidden Layer 
model.add(Dense(units = hidden_nodes_l5, activation = 'relu'))

# Output Layer
model.add(Dense(units = 1, activation = 'sigmoid'))

# Check model structure
model.summary()

# Compile model
optimizer = Adam(learning_rate=0.0001)
model.compile(optimizer = optimizer, loss = 'binary_crossentropy', metrics = ['accuracy'])

# Train model
model.fit(X_train, y_train, epochs = 16, batch_size = 10, validation_data = (X_test, y_test))

# Evaluate the model using the test data
loss, accuracy = model.evaluate(X_test ,y_test)
print(f"Test Loss: {round(loss,2)*100}%, Test Accuracy: {round(accuracy,2)*100}%")

Optimizing_final = pd.DataFrame({'Loss': [round(loss,2)], 'Accuracy': [round(accuracy,2)]})
Optimizing_final
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_17 (Dense)            (None, 100)               900
#
#  dense_18 (Dense)            (None, 80)                8080
#
#  dense_19 (Dense)            (None, 60)                4860
#
#  dense_20 (Dense)            (None, 40)                2440
#
#  dense_21 (Dense)            (None, 30)                1230
#
#  dense_22 (Dense)            (None, 1)                 31
#
# =================================================================
# Total params: 17541 (68.52 KB)
# Trainable params: 17541 (68.52 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/16
# 1098/1098 [==============================] - 1s 671us/step - loss: 0.0852 - accuracy: 0.9666 - val_loss: 0.0240 - val_accuracy: 0.9675
# Epoch 2/16
# 1098/1098 [==============================] - 1s 609us/step - loss: 0.0199 - accuracy: 0.9666 - val_loss: 0.0186 - val_accuracy: 0.9675
# Epoch 3/16
# 1098/1098 [==============================] - 1s 625us/step - loss: 0.0176 - accuracy: 0.9666 - val_loss: 0.0171 - val_accuracy: 0.9675
# Epoch 4/16
# 1098/1098 [==============================] - 1s 615us/step - loss: 0.0164 - accuracy: 0.9666 - val_loss: 0.0170 - val_accuracy: 0.9675
# Epoch 5/16
# 1098/1098 [==============================] - 1s 604us/step - loss: 0.0159 - accuracy: 0.9666 - val_loss: 0.0177 - val_accuracy: 0.9675
# Epoch 6/16
# 1098/1098 [==============================] - 1s 615us/step - loss: 0.0154 - accuracy: 0.9666 - val_loss: 0.0165 - val_accuracy: 0.9675
# Epoch 7/16
# 1098/1098 [==============================] - 1s 612us/step - loss: 0.0153 - accuracy: 0.9666 - val_loss: 0.0153 - val_accuracy: 0.9675
# Epoch 8/16
# 1098/1098 [==============================] - 1s 608us/step - loss: 0.0151 - accuracy: 0.9666 - val_loss: 0.0152 - val_accuracy: 0.9675
# Epoch 9/16
# 1098/1098 [==============================] - 1s 622us/step - loss: 0.0147 - accuracy: 0.9666 - val_loss: 0.0150 - val_accuracy: 0.9675
# Epoch 10/16
# 1098/1098 [==============================] - 1s 620us/step - loss: 0.0145 - accuracy: 0.9666 - val_loss: 0.0149 - val_accuracy: 0.9675
# Epoch 11/16
# 1098/1098 [==============================] - 1s 608us/step - loss: 0.0143 - accuracy: 0.9666 - val_loss: 0.0155 - val_accuracy: 0.9675
# Epoch 12/16
# 1098/1098 [==============================] - 1s 609us/step - loss: 0.0142 - accuracy: 0.9666 - val_loss: 0.0157 - val_accuracy: 0.9675
# Epoch 13/16
# 1098/1098 [==============================] - 1s 603us/step - loss: 0.0140 - accuracy: 0.9666 - val_loss: 0.0148 - val_accuracy: 0.9675
# Epoch 14/16
# 1098/1098 [==============================] - 1s 607us/step - loss: 0.0140 - accuracy: 0.9666 - val_loss: 0.0145 - val_accuracy: 0.9675
# Epoch 15/16
# 1098/1098 [==============================] - 1s 607us/step - loss: 0.0139 - accuracy: 0.9666 - val_loss: 0.0147 - val_accuracy: 0.9675
# Epoch 16/16
# 1098/1098 [==============================] - 1s 625us/step - loss: 0.0137 - accuracy: 0.9666 - val_loss: 0.0150 - val_accuracy: 0.9675
# 115/115 [==============================] - 0s 369us/step - loss: 0.0150 - accuracy: 0.9675
# Test Loss: 1.0%, Test Accuracy: 97.0%
#    Loss  Accuracy
# 0  0.01      0.97

# %%
# Put all the model optimizations into one dataframe to view results

analysis = pd.concat([model_original, Optimizing_1, Optimizing_2, Optimizing_3, Optimizing_final], ignore_index = True)
analysis = analysis.rename(index = {
    0: 'Original Model',
    1: '1st Model Optimization',
    2: '2nd Model Optimization',
    3: '3rd Model Optimization',
    4: 'Final Model Optimization'
})

analysis
# Out:
#                           Loss  Accuracy
# Original Model            0.02      0.97
# 1st Model Optimization    0.02      0.97
# 2nd Model Optimization    0.02      0.97
# 3rd Model Optimization    0.02      0.97
# Final Model Optimization  0.01      0.97
