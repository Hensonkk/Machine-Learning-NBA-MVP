# %%
import pandas as pd
import numpy as np

# %%
file_1 = "../Datasets/all_nba_seasons.csv"
file_2 = "../Datasets/all_nba_seasons_revised.csv"
file_3 = "../Datasets/historical_RAPTOR_by_team.csv"
file_4 = "../Datasets/latest_RAPTOR_by_team.csv"
file_5 = "../Datasets/mvps.csv"
file_6 = "../Datasets/mvps2022_2023.csv"
file_7 = "../Datasets/mvps_stats_all_seasons_revised.csv"
file_8 = "../Datasets/nba_player_injuries.csv"
file_9 = "../Datasets/player_mvp_stats.csv"
file_10 = "../Datasets/stats_2022_2023.csv"

# %%
#data = pd.read_csv(file_1)
#data = pd.read_csv(file_2)
#data = pd.read_csv(file_3)
#data = pd.read_csv(file_4)
#data = pd.read_csv(file_5)
#data = pd.read_csv(file_6)
data = pd.read_csv(file_7)
#data = pd.read_csv(file_8)
#data = pd.read_csv(file_9)
#data = pd.read_csv(file_10)

# %%
data.head()
# Out:
#    Unnamed: 0   Season Rank          Player Pos  Age   G    MP   PTS  AST  \
# 0           0  1996-97    1     Karl Malone  PF   33  82  36.6  27.4  4.5
# 1           1  1996-97    2  Michael Jordan  SG   33  82  37.9  29.6  4.3
# 2           2  1996-97    3      Grant Hill  SF   24  80  39.3  21.4  7.3
# 3           3  1996-97    4    Tim Hardaway  PG   30  81  38.7  20.3  8.6
# 4           4  1996-97    5       Glen Rice  SF   29  79  42.6  26.8  2.0
#
#    ...   eFG%    FT%   PF    WS  WS/48  First  Pts Won  Pts Max  Share  MVP
# 0  ...  0.550  0.755  2.6  16.7  0.268     63      986     1150  0.857    1
# 1  ...  0.516  0.833  1.9  18.3  0.283     52      957     1150  0.832    0
# 2  ...  0.500  0.711  2.3  14.6  0.223      0      376     1150  0.327    0
# 3  ...  0.489  0.799  2.0  12.9  0.198      0      238     1150  0.207    0
# 4  ...  0.546  0.867  2.4  10.8  0.154      0      134     1150  0.117    0
#
# [5 rows x 24 columns]

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#      Unnamed: 0   Season Rank          Player Pos  Age   G    MP   PTS  AST  \
# 0             0  1996-97    1     Karl Malone  PF   33  82  36.6  27.4  4.5
# 1             1  1996-97    2  Michael Jordan  SG   33  82  37.9  29.6  4.3
# 2             2  1996-97    3      Grant Hill  SF   24  80  39.3  21.4  7.3
# 3             3  1996-97    4    Tim Hardaway  PG   30  81  38.7  20.3  8.6
# 4             4  1996-97    5       Glen Rice  SF   29  79  42.6  26.8  2.0
# ..          ...      ...  ...             ...  ..  ...  ..   ...   ...  ...
# 393         393  2022-23    9   Stephen Curry  PG   34  56  34.7  29.4  6.3
# 394         394  2022-23   10    Jimmy Butler  PF   33  64  33.4  22.9  5.3
# 395         395  2022-23   11    De'Aaron Fox  PG   25  73  33.4  25.0  6.1
# 396         396  2022-23  12T   Jalen Brunson  PG   26  68  35.0  24.0  6.2
# 397         397  2022-23  12T       Ja Morant  PG   23  61  31.9  26.2  8.1
#
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Season', 'Rank', 'Player', 'Pos', 'Age', 'G', 'MP',
#        'PTS', 'AST', 'TRB', 'STL', 'BLK', 'FG%', 'eFG%', 'FT%', 'PF', 'WS',
#        'WS/48', 'First', 'Pts Won', 'Pts Max', 'Share', 'MVP'],
#       dtype='object')

# %%
df[df["MVP"] == 1]
# Out:
#      Unnamed: 0   Season Rank                 Player Pos  Age   G    MP   PTS  \
# 0             0  1996-97    1            Karl Malone  PF   33  82  36.6  27.4
# 20           20  1997-98    1         Michael Jordan  SG   34  82  38.8  28.7
# 39           39  1998-99    1            Karl Malone  PF   35  49  37.4  23.8
# 60           60  1999-00    1       Shaquille O'Neal   C   27  79  40.0  29.7
# 76           76  2000-01    1          Allen Iverson  SG   25  71  42.0  31.1
# 93           93  2001-02    1             Tim Duncan  PF   25  82  40.6  25.5
# 111         111  2002-03    1             Tim Duncan  PF   26  81  39.3  23.3
# 124         124  2003-04    1          Kevin Garnett  PF   27  82  39.4  24.2
# 139         139  2004-05    1             Steve Nash  PG   30  75  34.3  15.5
# 155         155  2005-06    1             Steve Nash  PG   31  79  35.4  18.8
# 166         166  2006-07    1          Dirk Nowitzki  PF   28  78  36.2  24.6
# ...
