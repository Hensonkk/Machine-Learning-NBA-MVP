# %%
# Load in the modules needed for preprocessing the Data

import pandas as pd
import numpy as np

# %%
# Read the CSV file for All NBA Season statistics into a Pandas Dataframe

nba_df = pd.read_csv("Datasets/all_nba_seasons.csv")
nba_df.head()
# Out:
#     Season               Player Pos  Age   G    MP   FG   FGA    FG%   3P  \
# 0  1996-97   Mahmoud Abdul-Rauf  PG   27  75  28.4  5.5  12.3  0.445  1.3
# 1  1996-97  Shareef Abdur-Rahim  PF   20  80  35.0  6.9  15.2  0.453  0.1
# 2  1996-97       Rafael Addison  SF   32  41   8.7  1.2   3.0  0.402  0.2
# 3  1996-97       Cory Alexander  PG   23  80  18.2  2.4   6.1  0.396  1.2
# 4  1996-97         Jerome Allen  SG   24  76  12.4  1.0   2.9  0.353  0.4
#
#    ...  DRB  TRB  AST  STL  BLK  TOV   PF   PTS   WS  WS/48
# 0  ...  1.4  1.6  2.5  0.7  0.1  1.6  2.3  13.7  2.7  0.060
# 1  ...  4.2  6.9  2.2  1.0  1.0  2.8  2.5  18.7  2.9  0.049
# 2  ...  0.6  1.1  0.8  0.2  0.1  0.4  1.3   3.1  0.4  0.048
# 3  ...  1.2  1.5  3.2  1.0  0.2  1.8  1.9   7.2  1.1  0.035
# 4  ...  1.0  1.3  2.0  0.4  0.1  0.9  1.1   3.0  0.4  0.021
#
# [5 rows x 30 columns]

# %%
# Drop unwanted columns from the Dataframe

nba_df = nba_df.drop(columns = ["FG", "FGA", "3P", "3PA", "3P%", "2P", "2PA", "2P%", "FT", "FTA", "ORB", "DRB", "TOV"])
nba_df.head()
# Out:
#     Season               Player Pos  Age   G    MP    FG%   eFG%    FT%  TRB  \
# 0  1996-97   Mahmoud Abdul-Rauf  PG   27  75  28.4  0.445  0.496  0.846  1.6
# 1  1996-97  Shareef Abdur-Rahim  PF   20  80  35.0  0.453  0.456  0.746  6.9
# 2  1996-97       Rafael Addison  SF   32  41   8.7  0.402  0.434  0.786  1.1
# 3  1996-97       Cory Alexander  PG   23  80  18.2  0.396  0.492  0.736  1.5
# 4  1996-97         Jerome Allen  SG   24  76  12.4  0.353  0.421  0.583  1.3
#
#    AST  STL  BLK   PF   PTS   WS  WS/48
# 0  2.5  0.7  0.1  2.3  13.7  2.7  0.060
# 1  2.2  1.0  1.0  2.5  18.7  2.9  0.049
# 2  0.8  0.2  0.1  1.3   3.1  0.4  0.048
# 3  3.2  1.0  0.2  1.9   7.2  1.1  0.035
# 4  2.0  0.4  0.1  1.1   3.0  0.4  0.021

# %%
# Filter out players by only selecting the players who score more than 5 points a game. 

nba_df2 = nba_df[nba_df["PTS"] > 5]
nba_df2
# Out:
#         Season               Player Pos  Age   G    MP    FG%   eFG%    FT%  \
# 0      1996-97   Mahmoud Abdul-Rauf  PG   27  75  28.4  0.445  0.496  0.846
# 1      1996-97  Shareef Abdur-Rahim  PF   20  80  35.0  0.453  0.456  0.746
# 3      1996-97       Cory Alexander  PG   23  80  18.2  0.396  0.492  0.736
# 7      1996-97            Ray Allen  SG   21  82  30.9  0.430  0.494  0.823
# 11     1996-97       Kenny Anderson  PG   26  82  37.6  0.427  0.485  0.768
# ...        ...                  ...  ..  ...  ..   ...    ...    ...    ...
# 16543  2023-24      Zion Williamson  PF   23  18  31.2  0.569  0.572  0.664
# 16546  2023-24        James Wiseman   C   22  10  11.1  0.649  0.649  0.545
# 16547  2023-24       Christian Wood  PF   28  21  20.2  0.443  0.504  0.689
# 16550  2023-24           Trae Young  PG   25  18  36.0  0.409  0.486  0.864
# 16553  2023-24          Ivica Zubac   C   26  19  25.8  0.627  0.627  0.621
#
#        TRB   AST  STL  BLK   PF   PTS    WS  WS/48
# ...

# %%
# Drop the duplicate players in each season, this is due to some players being traded and names appearing
# multiple times in one season

nba_df2.drop_duplicates(subset = ['Season', 'Player'], keep = 'first', inplace = True)
# Out:
# /var/folders/jq/v09bhc5d2111vbxp7qgxxq4m0000gn/T/ipykernel_27126/568551810.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nba_df2.drop_duplicates(subset = ['Season', 'Player'], keep = 'first', inplace = True)

# %%
# Create a new column for MVP and assign non value to it

nba_df2["MVP"] = np.nan
# Out:
# /var/folders/jq/v09bhc5d2111vbxp7qgxxq4m0000gn/T/ipykernel_27126/1391910707.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nba_df2["MVP"] = np.nan

# %%
# Display dataframe after adjusments are made

nba_df2
# Out:
#         Season               Player Pos  Age   G    MP    FG%   eFG%    FT%  \
# 0      1996-97   Mahmoud Abdul-Rauf  PG   27  75  28.4  0.445  0.496  0.846
# 1      1996-97  Shareef Abdur-Rahim  PF   20  80  35.0  0.453  0.456  0.746
# 3      1996-97       Cory Alexander  PG   23  80  18.2  0.396  0.492  0.736
# 7      1996-97            Ray Allen  SG   21  82  30.9  0.430  0.494  0.823
# 11     1996-97       Kenny Anderson  PG   26  82  37.6  0.427  0.485  0.768
# ...        ...                  ...  ..  ...  ..   ...    ...    ...    ...
# 16543  2023-24      Zion Williamson  PF   23  18  31.2  0.569  0.572  0.664
# 16546  2023-24        James Wiseman   C   22  10  11.1  0.649  0.649  0.545
# 16547  2023-24       Christian Wood  PF   28  21  20.2  0.443  0.504  0.689
# 16550  2023-24           Trae Young  PG   25  18  36.0  0.409  0.486  0.864
# 16553  2023-24          Ivica Zubac   C   26  19  25.8  0.627  0.627  0.621
#
#        TRB   AST  STL  BLK   PF   PTS    WS  WS/48  MVP
# ...

# %%
# Set the column order

columns_order = ["Season", "Player", "Pos", "Age", "G", "MP", "PTS", "AST", "TRB", "STL", "BLK", "FG%", "eFG%", "FT%", "PF", "WS", "WS/48", "MVP"]

# %%
# Restructure the dataframe to the desired column order

nba_df2 = nba_df2[columns_order]
nba_df2
# Out:
#         Season               Player Pos  Age   G    MP   PTS   AST  TRB  STL  \
# 0      1996-97   Mahmoud Abdul-Rauf  PG   27  75  28.4  13.7   2.5  1.6  0.7
# 1      1996-97  Shareef Abdur-Rahim  PF   20  80  35.0  18.7   2.2  6.9  1.0
# 3      1996-97       Cory Alexander  PG   23  80  18.2   7.2   3.2  1.5  1.0
# 7      1996-97            Ray Allen  SG   21  82  30.9  13.4   2.6  4.0  0.9
# 11     1996-97       Kenny Anderson  PG   26  82  37.6  17.5   7.1  4.4  2.0
# ...        ...                  ...  ..  ...  ..   ...   ...   ...  ...  ...
# 16543  2023-24      Zion Williamson  PF   23  18  31.2  22.7   4.9  5.8  1.2
# 16546  2023-24        James Wiseman   C   22  10  11.1   5.4   0.3  3.2  0.1
# 16547  2023-24       Christian Wood  PF   28  21  20.2   7.0   0.8  5.9  0.2
# 16550  2023-24           Trae Young  PG   25  18  36.0  27.1  10.7  2.9  1.6
# 16553  2023-24          Ivica Zubac   C   26  19  25.8  11.8   0.8  9.0  0.1
#
# ...

# %%
# Export the dataframe into a csv file in our Datasets folder

nba_df2.to_csv("Datasets/all_nba_seasons_revised.csv")

# %%
# Read the CSV file for players who won MVP and were in the MVP race for each season into a Pandas Dataframe

mvp_candidates = pd.read_csv("Datasets/mvps.csv", encoding='unicode_escape')
mvp_candidates
# Out:
#       Season Rank           Player  Age   Tm  First  Pts Won  Pts Max  Share  \
# 0    1990-91    1   Michael Jordan   27  CHI     77      891      960  0.928
# 1    1990-91    2    Magic Johnson   31  LAL     10      497      960  0.518
# 2    1990-91    3   David Robinson   25  SAS      6      476      960  0.496
# 3    1990-91    4  Charles Barkley   27  PHI      2      222      960  0.231
# 4    1990-91    5      Karl Malone   27  UTA      0      142      960  0.148
# ..       ...  ...              ...  ...  ...    ...      ...      ...    ...
# 494  2022-23    9    Stephen Curry   34  GSW      0        5     1000  0.005
# 495  2022-23   10     Jimmy Butler   33  MIA      0        3     1000  0.003
# 496  2022-23   11     De'Aaron Fox   25  SAC      0        2     1000  0.002
# 497  2022-23  12T    Jalen Brunson   26  NYK      0        1     1000  0.001
# 498  2022-23  12T        Ja Morant   23  MEM      0        1     1000  0.001
#
# ...

# %%
# Filter out dataframe for our desired seasons, starting from 1996-97 NBA season

mvp_candidates = mvp_candidates[mvp_candidates["Season"] >= "1996-97"]
mvp_candidates
# Out:
#       Season Rank          Player  Age   Tm  First  Pts Won  Pts Max  Share  \
# 100  1996-97    1     Karl Malone   33  UTA     63      986     1150  0.857
# 101  1996-97    2  Michael Jordan   33  CHI     52      957     1150  0.832
# 102  1996-97    3      Grant Hill   24  DET      0      376     1150  0.327
# 103  1996-97    4    Tim Hardaway   30  MIA      0      238     1150  0.207
# 104  1996-97    5       Glen Rice   29  CHH      0      134     1150  0.117
# ..       ...  ...             ...  ...  ...    ...      ...      ...    ...
# 494  2022-23    9   Stephen Curry   34  GSW      0        5     1000  0.005
# 495  2022-23   10    Jimmy Butler   33  MIA      0        3     1000  0.003
# 496  2022-23   11    De'Aaron Fox   25  SAC      0        2     1000  0.002
# 497  2022-23  12T   Jalen Brunson   26  NYK      0        1     1000  0.001
# 498  2022-23  12T       Ja Morant   23  MEM      0        1     1000  0.001
#
# ...

# %%
# Drop columns that already exist in the statistics dataframe. We are dropping these here because we will merge
# the two dataframes and don't want to duplicate columns

mvp_candidates = mvp_candidates.drop(columns = ["Age", "Tm", "G", "MP", "PTS", "TRB", "AST", "STL", "BLK", "FG%", "3P%", "FT%", "WS", "WS/48"])
mvp_candidates
# Out:
#       Season Rank          Player  First  Pts Won  Pts Max  Share
# 100  1996-97    1     Karl Malone     63      986     1150  0.857
# 101  1996-97    2  Michael Jordan     52      957     1150  0.832
# 102  1996-97    3      Grant Hill      0      376     1150  0.327
# 103  1996-97    4    Tim Hardaway      0      238     1150  0.207
# 104  1996-97    5       Glen Rice      0      134     1150  0.117
# ..       ...  ...             ...    ...      ...      ...    ...
# 494  2022-23    9   Stephen Curry      0        5     1000  0.005
# 495  2022-23   10    Jimmy Butler      0        3     1000  0.003
# 496  2022-23   11    De'Aaron Fox      0        2     1000  0.002
# 497  2022-23  12T   Jalen Brunson      0        1     1000  0.001
# 498  2022-23  12T       Ja Morant      0        1     1000  0.001
#
# [399 rows x 7 columns]

# %%
# Merge the two dataframes into one combined dataframe

nba_combined = pd.merge(mvp_candidates, nba_df2, on = ["Season", "Player"])

# %%
nba_combined
# Out:
#       Season Rank          Player  First  Pts Won  Pts Max  Share Pos  Age  \
# 0    1996-97    1     Karl Malone     63      986     1150  0.857  PF   33
# 1    1996-97    2  Michael Jordan     52      957     1150  0.832  SG   33
# 2    1996-97    3      Grant Hill      0      376     1150  0.327  SF   24
# 3    1996-97    4    Tim Hardaway      0      238     1150  0.207  PG   30
# 4    1996-97    5       Glen Rice      0      134     1150  0.117  SF   29
# ..       ...  ...             ...    ...      ...      ...    ...  ..  ...
# 393  2022-23    9   Stephen Curry      0        5     1000  0.005  PG   34
# 394  2022-23   10    Jimmy Butler      0        3     1000  0.003  PF   33
# 395  2022-23   11    De'Aaron Fox      0        2     1000  0.002  PG   25
# 396  2022-23  12T   Jalen Brunson      0        1     1000  0.001  PG   26
# 397  2022-23  12T       Ja Morant      0        1     1000  0.001  PG   23
#
# ...

# %%
# Set the column order

column_order = ["Season", "Rank", "Player", "Pos", "Age", "G", "MP", "PTS", "AST", "TRB", "STL", "BLK", "FG%", "eFG%", "FT%", "PF", "WS", "WS/48","First", "Pts Won", "Pts Max", "Share", "MVP"]

# %%
# Restructure the dataframe to the desired column order

nba_combined = nba_combined[column_order]

# %%
# Display dataframe after adjusments are made

nba_combined
# Out:
#       Season Rank          Player Pos  Age   G    MP   PTS  AST  TRB  ...  \
# 0    1996-97    1     Karl Malone  PF   33  82  36.6  27.4  4.5  9.9  ...
# 1    1996-97    2  Michael Jordan  SG   33  82  37.9  29.6  4.3  5.9  ...
# 2    1996-97    3      Grant Hill  SF   24  80  39.3  21.4  7.3  9.0  ...
# 3    1996-97    4    Tim Hardaway  PG   30  81  38.7  20.3  8.6  3.4  ...
# 4    1996-97    5       Glen Rice  SF   29  79  42.6  26.8  2.0  4.0  ...
# ..       ...  ...             ...  ..  ...  ..   ...   ...  ...  ...  ...
# 393  2022-23    9   Stephen Curry  PG   34  56  34.7  29.4  6.3  6.1  ...
# 394  2022-23   10    Jimmy Butler  PF   33  64  33.4  22.9  5.3  5.9  ...
# 395  2022-23   11    De'Aaron Fox  PG   25  73  33.4  25.0  6.1  4.2  ...
# 396  2022-23  12T   Jalen Brunson  PG   26  68  35.0  24.0  6.2  3.5  ...
# 397  2022-23  12T       Ja Morant  PG   23  61  31.9  26.2  8.1  5.9  ...
#
#       eFG%    FT%   PF    WS  WS/48  First  Pts Won  Pts Max  Share  MVP
# ...

# %%
# Using the "Rank" column, if the player has a Rank of 1, add a 1 to the MVP column, otherwise make MVP column 0

nba_combined["MVP"] = nba_combined["Rank"].apply(lambda x: '1' if x == '1' else '0')

# %%
# Display combined dataframe after adjustments are made

nba_combined
# Out:
#       Season Rank          Player Pos  Age   G    MP   PTS  AST  TRB  ...  \
# 0    1996-97    1     Karl Malone  PF   33  82  36.6  27.4  4.5  9.9  ...
# 1    1996-97    2  Michael Jordan  SG   33  82  37.9  29.6  4.3  5.9  ...
# 2    1996-97    3      Grant Hill  SF   24  80  39.3  21.4  7.3  9.0  ...
# 3    1996-97    4    Tim Hardaway  PG   30  81  38.7  20.3  8.6  3.4  ...
# 4    1996-97    5       Glen Rice  SF   29  79  42.6  26.8  2.0  4.0  ...
# ..       ...  ...             ...  ..  ...  ..   ...   ...  ...  ...  ...
# 393  2022-23    9   Stephen Curry  PG   34  56  34.7  29.4  6.3  6.1  ...
# 394  2022-23   10    Jimmy Butler  PF   33  64  33.4  22.9  5.3  5.9  ...
# 395  2022-23   11    De'Aaron Fox  PG   25  73  33.4  25.0  6.1  4.2  ...
# 396  2022-23  12T   Jalen Brunson  PG   26  68  35.0  24.0  6.2  3.5  ...
# 397  2022-23  12T       Ja Morant  PG   23  61  31.9  26.2  8.1  5.9  ...
#
#       eFG%    FT%   PF    WS  WS/48  First  Pts Won  Pts Max  Share  MVP
# ...

# %%
# Save the NBA combined DataFrame
nba_combined.to_csv("Datasets/mvps_stats_all_seasons_revised.csv")

# %%
# Load the RAPTOR data
latest_raptor_df = pd.read_csv('Datasets/latest_RAPTOR_by_team.csv', usecols=['player_name', 'season', 'raptor_offense', 'raptor_defense', 'predator_offense', 'predator_defense'])
historical_raptor_df = pd.read_csv('Datasets/historical_RAPTOR_by_team.csv', usecols=['player_name', 'season', 'raptor_offense', 'raptor_defense', 'predator_offense', 'predator_defense'])

# Convert the 'season' column in RAPTOR dataframes to string
latest_raptor_df['season'] = latest_raptor_df['season'].astype(str)
historical_raptor_df['season'] = historical_raptor_df['season'].astype(str)

# Merge the RAPTOR dataframes
raptor_df = pd.concat([latest_raptor_df, historical_raptor_df]).drop_duplicates(subset=['player_name', 'season'])

# Adjust the 'Season' column in nba_combined to match the 'season' format in RAPTOR data
def convert_season(season):
    year = season.split('-')[1]
    if int(year) < 50:  # Year cut off is 2050
        return '20' + year
    else:
        return '19' + year

nba_combined['Season'] = nba_combined['Season'].apply(convert_season)

# Merge the combined RAPTOR data with the nba_combined DataFrame
nba_combined = nba_combined.merge(raptor_df, left_on=['Player', 'Season'], right_on=['player_name', 'season'], how='left')

# Drop redundant columns
nba_combined.drop(['player_name', 'season'], axis=1, inplace=True)

# %%
# Save the merged DataFrame
nba_combined.to_csv("Datasets/RAPTOR_all_seasons.csv")
